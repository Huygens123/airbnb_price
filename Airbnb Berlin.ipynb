# %% [markdown]
# <h1 style="color:#323232;font-size:50px;font-family:Georgia;text-align:center;"><strong> Berlin Airbnb Ratings and Reviews: Quality Ratings of Properties and Experiences for Guests</h1>
#
# <h1 style="color:#323232;font-size:40px;font-family:Georgia;text-align:center;"><strong>Author: Abdulquawiyy A. Owolabi</b></h1>
# <h2 style= "font-family:Georgia;color:#000000;font-size:10%;text-align:center;border-radius:10px 50px;border-style: dotted;border-height:10px; border-width:2px;border-color:#323232; font-size:30px;"><strong>Content<br>
#
# 1. About
# 2. Exploratory Data Analysis
# 3. Feature Engineering
# 4. Feature Building
# 5. Model Building
# 6. Model Deployment

# %% [markdown]
# # About

# %% [markdown]
# > This [dataset](https://www.kaggle.com/datasets/thedevastator/berlin-airbnb-ratings-and-reviews-overview?select=Airbnb+Berlin.csv) contains information about more than 18,000 Airbnb listings in Berlin, covering ratings and reviews from guests. It includes data on listing URL, host name and URL, listing name and type, country code, location coordinates and exact address location details along with the amenities offered. Guests' comments are also recorded for each property. Detailed metric ratings are available for each individual property's overall score as well as its accuracy rating, cleanliness rating checkout process rating communication with host rating and value for money rating. In addition to the ratings provided by guests a lot of other relevant information like price per night number of bedrooms number of bathrooms square feet can be accessed through this dataset It also offers an indication of whether a given property is bookable without contacting the host (Instant Bookable) or if the Host is Superhost etc. This comprehensive dataset allows you to explore what factors make certain Airbnb properties in Berlin highly rated by guests!
#
# ![](https://storage.googleapis.com/kaggle-datasets-images/2802487/4836176/409b3559055d20aadda4958beaac75e4/dataset-cover.png)

# %% [markdown]
# ## Columns name

# %% [markdown]
# Column name | Description|
# ------------| ------------
# review_date | Date of the review. (Date)
# Reviewer Name|Name of the reviewer. (String)
# Comments|Comments made by the reviewer. (String)
# Listing URL|URL of the listing. (URL)
# Listing Name|Name of the listing. (String)
# Host URL|URL of the host. (URL)
# Host Name|Name of the host. (String)
# Host Since|Date the host joined Airbnb. (Date)
# Host Response Time|Time it takes for the host to respond to inquiries. (String)
# Host Response Rate|Percentage of inquiries the host responds to. (Number)
# Is Superhost|Whether or not the host is a Superhost. (Boolean)
# neighbourhood|Neighborhood of the listing. (String)
# Neighborhood Group|Group of neighborhoods the listing is in. (String)
# City|City the listing is located in. (String)
# Postal Code|Postal code of the listing. (String)
# Country Code|Country code of the listing. (String)
# Latitude|Latitude of the listing. (Number)
# Longitude|Longitude of the listing. (Number)
# Is Exact Location|Whether or not the location is exact. (Boolean)
# Property Type|Type of property (e.g. apartment, house, etc). (String)
# Room Type|Type of room (e.g. private, shared, etc). (String)
# Accomodates|Number of people the property can accommodate. (Number)
# Bathrooms|Number of bathrooms in the property. (Number)
# Bedrooms|Number of bedrooms in the property. (Number)
# Beds|Number of beds in the property. (Number)
# Square Feet|Size of the property in square feet. (Number)
# Price|Price of the property per night. (Number)
# Guests Included|Number of guests included in the price. (Number)
# Min Nights|Minimum number of nights required for booking. (Number)
# Reviews|Number of reviews for the property. (Number)
# First Review|Date of the first review. (Date)
# Last Review|Date of the last review. (Date)
# Overall Rating|Overall rating of the property. (Number)
# Accuracy Rating|Rating of the accuracy of the listing description. (Number)
# Cleanliness Rating|Rating of the cleanliness of the property. (Number)
# Checkin Rating|Rating of the check-in process. (Number)
# Communication Rating|Rating of the communication with the host. (Number)
# Location Rating|Rating of the location of the property. (Number)
# Value Rating|Rating of the value for money offered. (Number)
# Instant Bookable|Whether or not the property is instantly bookable. (Boolean)
# Business Travel Ready|Whether or not the property is suitable for business travel. (Boolean)

# %% [markdown]
# ## Question
# > - Analyzing the prices of Airbnb properties in Berlin.
# >
# > - Utilizing the data collected from each listing to create predictive models for prices and ratings of future Airbnb listings in different neighborhoods or cities. This can help hosts set appropriate rates for their listings and optimize their success rate on hosting platforms like Airbnb

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# > In this section, we shall look into the data to gain insights and understandings to:
#
# 1. Missing Values and Duplicated rows
# 2. All The Numerical Variables
# 3. Distribution of the Numerical Variables
# 4. Categorical Variables
# 5. Cardinality of Categorical Variables
# 6. Outliers
# 7. Relationship between independent and dependent feature(CANCELLED)

# %%
# import libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns;sns.set_style('darkgrid')
import plotly.express as px
import matplotlib
# %matplotlib inline
from sklearn.tree import plot_tree, export_text
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from urllib.request import urlretrieve
import opendatasets as od


# Configuring styles
sns.set_style('dark')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9,6)
matplotlib.rcParams['figure.facecolor'] = '#00000000'
colors = ["#8ecae6","#219ebc","#023047","#ffb703","#fb8500"]                       # colors to be used
sns.palplot(sns.color_palette(colors));

# %% [markdown]
# > Download dataset

# %%
data_url = 'https://www.kaggle.com/datasets/thedevastator/berlin-airbnb-ratings-and-reviews-overview?select=Airbnb+Berlin.csv'
data = od.download(data_url)
data
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: huygens
# Your Kaggle Key: ········
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12944\329185943.py in <module>
#       1 data_url = 'https://www.kaggle.com/datasets/thedevastator/berlin-airbnb-ratings-and-reviews-overview?select=Airbnb+Berlin.csv'
# ----> 2 data = od.download(data_url)
#       3 data
#
# ~\anaconda3\lib\site-packages\opendatasets\__init__.py in download(dataset_id_or_url, data_dir, force, dry_run, **kwargs)
#      11     # Check for a Kaggle dataset URL
#      12     if is_kaggle_url(dataset_id_or_url):
# ---> 13         return download_kaggle_dataset(dataset_id_or_url, data_dir=data_dir, force=force, dry_run=dry_run)
#      14
#      15     # Check for Google Drive URL
#
# ...

# %%
urlretrieve(medical_charges_url, 'Airbnb Berlin.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12944\1725894978.py in <module>
# ----> 1 urlretrieve(medical_charges_url, 'Airbnb Berlin.csv')
#
# NameError: name 'urlretrieve' is not defined

# %%
#import dataset
airbnb_df = pd.read_csv('Airbnb Berlin.csv', low_memory=False)
airbnb_df.sample(3).T
# Out:
#                                                                   95909   \
# index                                                              95909
# Review ID                                                    164103546.0
# review_date                                                     06-26-17
# Reviewer ID                                                   23488060.0
# Reviewer Name                                                       Lola
# Comments               Excelente hospedaje, Hardi es increÃ­blemente ...
# Listing ID                                                      15652886
# Listing URL                        https://www.airbnb.com/rooms/15652886
# Listing Name               Cozy and quiet room in old building in Berlin
# Host ID                                                        101017638
# Host URL                     https://www.airbnb.com/users/show/101017638
# Host Name                                                          Hardi
# ...

# %%
# check duplicated rows
airbnb_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# > No duplicated dataset

# %%
# check statistical description of the dataset
airbnb_df.describe().T
# Out:
#                          count          mean           std         min  \
# index                 456961.0  2.284800e+05  1.319134e+05     0.00000
# Review ID             452805.0  2.210771e+08  1.298566e+08  4283.00000
# Reviewer ID           452805.0  6.741881e+07  6.445677e+07     5.00000
# Listing ID            456961.0  1.172870e+07  9.105569e+06  2695.00000
# Host ID               456961.0  4.225116e+07  5.475489e+07  1581.00000
# Latitude              456961.0  5.251246e+01  2.889243e-02    52.34580
# Longitude             456961.0  1.340345e+01  5.517254e-02    13.09718
# Accomodates           456961.0  3.102133e+00  1.928835e+00     1.00000
# Bathrooms             456018.0  1.099039e+00  3.376969e-01     0.00000
# Bedrooms              456244.0  1.216042e+00  7.205002e-01     0.00000
# Beds                  456871.0  1.912006e+00  1.525296e+00     0.00000
# Square Feet            28675.0  4.197217e+02  5.415675e+02     0.00000
# ...

# %% [markdown]
# > Clearly, the following column shows the presence of outliers:
# 1. `Review`
# 2. `Min Nights`
# 3. `Square Feet`

# %% [markdown]
# ## Missing Values
#
# > Here, I will deal wth the missing values and check the best way to get rid of them

# %%
missing_vals = [features for features in airbnb_df.columns if airbnb_df[features].isnull().sum() >=1]

for feature in missing_vals:
    print(feature, np.round(airbnb_df[feature].isnull().mean(), 3), 'average null values')
# Out:
# Review ID 0.009 average null values
# review_date 0.009 average null values
# Reviewer ID 0.009 average null values
# Reviewer Name 0.009 average null values
# Comments 0.01 average null values
# Listing Name 0.0 average null values
# Host Name 0.0 average null values
# Host Since 0.0 average null values
# Host Response Time 0.129 average null values
# Host Response Rate 0.129 average null values
# Is Superhost 0.0 average null values
# City 0.0 average null values
# Postal Code 0.017 average null values
# Bathrooms 0.002 average null values
# Bedrooms 0.002 average null values
# Beds 0.0 average null values
# Square Feet 0.937 average null values
# First Review 0.009 average null values
# Last Review 0.009 average null values
# Overall Rating 0.01 average null values
# Accuracy Rating 0.01 average null values
# Cleanliness Rating 0.01 average null values
# Checkin Rating 0.01 average null values
# Communication Rating 0.01 average null values
# ...

# %% [markdown]
# >The missing values in each col are small which can be drop except `Square feet`
# Now, let us plot the missing values versus the non-missing values againts the median price.
# >
# >Before that, the price column is in object datatype because comma was added to values taht are thousand and above

# %%
airbnb_df['Price'] = airbnb_df['Price'].apply(lambda x: x.replace(",", '') if ',' in x else x).astype(float)

# %% [markdown]
# > Now plot the missing values against non missing with missing designated as 0, while non missing is 1

# %%
for feature in missing_vals:
    data = airbnb_df.copy()
    
    # assign 0 to null and 1 to nunnull
    data[feature] = np.where(data[feature].isnull(), 0, 1)
    
    #plot
    data.groupby(feature)['Price'].sum().plot.bar()
    plt.title(feature)
    plt.ylabel('median price')
    plt.xlabel(feature)
    plt.show()

# %%
# Since the null values are not much, I will deal with them in the Future Engineering section

# %%
airbnb_df.dropna(inplace=True)

# %% [markdown]
# ## Numerical Columns

# %% [markdown]
# > Check for the number of unique values in each column

# %%
airbnb_df.nunique()
# Out:
# index                    26621
# Review ID                26621
# review_date               2747
# Reviewer ID              26212
# Reviewer Name             8159
# Comments                 26400
# Listing ID                 293
# Listing URL                293
# Listing Name               293
# Host ID                    255
# Host URL                   255
# Host Name                  218
# Host Since                 231
# Host Response Time           4
# Host Response Rate          20
# Is Superhost                 2
# neighbourhood               40
# Neighborhood Group          11
# City                         4
# Postal Code                113
# Country Code                 1
# Country                      1
# Latitude                   292
# Longitude                  292
# Is Exact Location            2
# Property Type               11
# Room Type                    3
# Accomodates                 14
# Bathrooms                    6
# Bedrooms                     6
# ...

# %% [markdown]
# > Before dealing with the numerical columns, I will drop the following columns because they are IDs or only contain 1 unique value

# %%
drop_cols = ['Host ID','Listing ID','Reviewer ID',
             'Review ID','index', 'Longitude', 'Latitude', 'Business Travel Ready', 'Country Code']

# %%
airbnb_df.drop(labels=drop_cols, axis=1, inplace=True)

# %% [markdown]
# > Check the number of numerical columns in the dataset

# %%
numVar = [feature for feature in airbnb_df.columns if airbnb_df[feature].dtype != 'O']
print('Numerical Columns: ', len(feature))
# Out:
# Numerical Columns:  12

# %% [markdown]
# ### Temporal Columns

# %% [markdown]
# > Let us deal with temporal datset first
# >
# > Extract columns that are temporal and check their relationships with the Prie column

# %%
date_col = ['review_date', 'Host Since', 'First Review', 'Last Review']

# %% [markdown]
# > Convert these columns to datatime type

# %%
airbnb_df['review_date'] = pd.to_datetime(airbnb_df['review_date'], dayfirst=False)
airbnb_df['Host Since'] = pd.to_datetime(airbnb_df['Host Since'], dayfirst=False)
airbnb_df['First Review'] = pd.to_datetime(airbnb_df['First Review'], dayfirst=False)
airbnb_df['Last Review'] = pd.to_datetime(airbnb_df['Last Review'], dayfirst=False)

# %% [markdown]
# > Now, I will compare this with median price

# %%
for col in date_col:
    data = airbnb_df.copy()
    plt.scatter(airbnb_df[col], airbnb_df.Price)
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('Median Price')
    plt.show()

# %% [markdown]
# ## Discrete Column

# %% [markdown]
# >There are two type of numerical variables viz:
# 1. Continuous: has many unique values
# 2. Discreet: small or little unique value.
# >
# > Here, discrete variables shall be consider first
# >
# >
# >Extract discreet columns and viszualise them using bars. The median price in each category will be consider

# %%
discrete_col = [cols for cols in airbnb_df[numVar].columns if len(airbnb_df[cols].unique()) <= 20]

for col in discrete_col:
    data = airbnb_df.copy()
    data.groupby(col)['Price'].median().plot.bar()
    plt.ylabel('Median Price')
    plt.show()

# %% [markdown]
# Observations:
# - `Accomodation`: As the accommodation size increases, the price increases as well. A kind of skewed to the left shape is formed which indicates that most high accomodating houses cost more money (price).
# - `Bathrooms` : Skewed to the left as well, which indicates that many bathrooms attract more money.
# - `Bedrooms`: 0 bedrooms costing more money than  and 2 bedrooms may indicates that the building is meant for other purposes.
# - `Bed` : Skewed to the left as well which indicates that more beds costs more money except 9 beded rooms and 15 beded room. This may indicate the presence of a outiler in the column.
# - `Accuracy Rating`: Higher prices attracts low `accuracy rating`, `checking rating`, `communication rating`, and `value rating`. This might speak volume of inconveniences in the ouse rent

# %% [markdown]
# > Next up, I will check the continous variables and plot a graph to check the relationship between them and the `Price` clumn

# %%
contVar = [cols for cols in airbnb_df[numVar].columns if len(airbnb_df[cols].unique()) > 20]
contVar
# Out:
# ['Square Feet', 'Price', 'Min Nights', 'Reviews', 'Overall Rating']

# %% [markdown]
# > Plot these using histogram

# %%
for col in contVar:
    data = airbnb_df.copy()
    data[col].hist(bins=10)
    plt.ylabel('Count')
    plt.xlabel(feature)
    plt.show()

# %% [markdown]
# ## Categorical Variables

# %%
catVar = [col for col in airbnb_df.columns if airbnb_df[col].dtypes == "O"]

# categories of feature in each column
for feature in catVar:
    print('The feature is {}, and number of categories are {}'.format(feature,len(airbnb_df[feature].unique())))
# Out:
# The feature is Reviewer Name, and number of categories are 8159
# The feature is Comments, and number of categories are 26400
# The feature is Listing URL, and number of categories are 293
# The feature is Listing Name, and number of categories are 293
# The feature is Host URL, and number of categories are 255
# The feature is Host Name, and number of categories are 218
# The feature is Host Response Time, and number of categories are 4
# The feature is Host Response Rate, and number of categories are 20
# The feature is Is Superhost, and number of categories are 2
# The feature is neighbourhood, and number of categories are 40
# The feature is Neighborhood Group, and number of categories are 11
# The feature is City, and number of categories are 4
# The feature is Postal Code, and number of categories are 113
# The feature is Country, and number of categories are 1
# The feature is Is Exact Location, and number of categories are 2
# ...

# %%
catVar = [col for col in airbnb_df[catVar].columns if airbnb_df[col].nunique() <= 50]
catVar
# Out:
# ['Host Response Time',
#  'Host Response Rate',
#  'Is Superhost',
#  'neighbourhood',
#  'Neighborhood Group',
#  'City',
#  'Country',
#  'Is Exact Location',
#  'Property Type',
#  'Room Type',
#  'Instant Bookable']

# %% [markdown]
# > Now, relationship between the categorical variables and the target column

# %%
for col in catVar:
    data = airbnb_df.copy()
    data.groupby(col)['Price'].mean().plot.bar()
    plt.ylabel('Median Price')
    plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 159 (\x9f) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Outlier

# %%
for feature in contVar:
    data=airbnb_df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data.boxplot(column=feature)
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# The following shall be examine:
# > - Create a training/test/validation split
# >
# > - Identify input and target columns
# >
# > - Impute missing numerical Value
# >
# > - Scale numerical values
# >
# > - Encode categorical columns using OneHotEncoder

# %% [markdown]
# ## Create a training/test/validation split

# %%
airbnb_df['review_date'] = pd.to_datetime(airbnb_df['review_date']).dt.year
airbnb_df = airbnb_df.sort_values(by=['review_date'])

# %%
train_val_df, test_df = train_test_split(airbnb_df, test_size=0.2, random_state=42)
train_df, val_df = train_test_split(train_val_df, test_size=0.25, random_state=42)

# %% [markdown]
# > I don't want the dataset to learn from future, so I will limit the training set to less than 2018 alone

# %%
year = airbnb_df.review_date

train_df = airbnb_df[year < 2018]
val_df = airbnb_df[year == 2018]
test_df = airbnb_df[year > 2018]

# %%
train_df.to_csv('airbnb_train.csv', index_label=False)
test_df.to_csv('airbnb_test.csv', index_label=False)
val_df.to_csv('airbnb_val.csv', index_label=False)

# %% [markdown]
# ## Identify input and target columns

# %% [markdown]
# > Create target and input columns that will be used for the model

# %%
numVar = numVar = [feature for feature in airbnb_df.columns if airbnb_df[feature].dtype != 'O' and feature not in date_col 
                   +['Price']]
input_cols = list(catVar  + numVar)
target_col = 'Price'

# %%
train_inputs = train_df[input_cols].copy()
train_targets = train_df[target_col].copy()
val_inputs = val_df[input_cols].copy()
val_targets = val_df[target_col].copy()
test_inputs = test_df[input_cols].copy()
test_targets = test_df[target_col].copy()

# %% [markdown]
# ## Scale numerical columns

# %%
scalar = MinMaxScaler().fit(airbnb_df[numVar])

# %%
test_inputs
# Out:
#        Host Response Time Host Response Rate Is Superhost    neighbourhood  \
# 269443     within an hour               100%            t  Prenzlauer Berg
# 228851     within an hour               100%            f           Moabit
# 269444     within an hour               100%            t  Prenzlauer Berg
# 269442     within an hour               100%            t  Prenzlauer Berg
# 228850     within an hour               100%            f           Moabit
# ...                   ...                ...          ...              ...
# 157292     within an hour               100%            f        NeukÃ¶lln
# 157291     within an hour               100%            f        NeukÃ¶lln
# 157290     within an hour               100%            f        NeukÃ¶lln
# 47686      within an hour               100%            f        Kreuzberg
# 35767      within an hour               100%            t           Pankow
#
# ...

# %%
train_inputs[numVar] = scalar.transform(train_inputs[numVar])
val_inputs[numVar] = scalar.transform(val_inputs[numVar])
test_inputs[numVar] = scalar.transform(test_inputs[numVar])

# %% [markdown]
# # Encode Categorical Columns

# %% [markdown]
# > Now, I will encode the categorcal column

# %%
encoder = OneHotEncoder(sparse=False, 
                        handle_unknown='ignore').fit(airbnb_df[catVar])
encoded_cols = list(encoder.get_feature_names_out(catVar))

# %%
train_inputs[encoded_cols] = encoder.transform(train_inputs[catVar])
val_inputs[encoded_cols] = encoder.transform(val_inputs[catVar])
test_inputs[encoded_cols] = encoder.transform(test_inputs[catVar])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12944\2367633651.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_inputs[encoded_cols] = encoder.transform(train_inputs[catVar])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12944\2367633651.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_inputs[encoded_cols] = encoder.transform(train_inputs[catVar])
# ...

# %%
X_train = train_inputs[numVar + encoded_cols]
X_val = val_inputs[numVar + encoded_cols]
X_test = test_inputs[numVar + encoded_cols ]

# %% [markdown]
# # Model Building With Decision Tree Regressor

# %% [markdown]
# > **Train a decision tree regressor using the training set.**

# %%
# create model
model1 = DecisionTreeRegressor(random_state=42)

# %% [markdown]
# > Fit the model to training inputs

# %%
# %%time
model1.fit(X_train, train_targets)
# Out:
# Wall time: 179 ms
# DecisionTreeRegressor(random_state=42)

# %% [markdown]
# ## Metrics Calculation

# %% [markdown]
# > Here, I will generate predictions on the training and validation sets using the trained decision tree, and compute the RMSE loss.

# %%
tree_train_preds = model1.predict(X_train)

# %%
train_rmse = mean_squared_error(tree_train_preds,train_targets,  squared=False)
train_rmse     #rmse loss
# Out:
# 0.0

# %%
tree_val_preds = model1.predict(X_val)

# %%
val_rmse = mean_squared_error(tree_val_preds, val_targets, squared=False)
val_rmse
# Out:
# 4.065613220345858

# %%
print('Train RMSE: {}, Validation RMSE: {}'.format(train_rmse, val_rmse))
# Out:
# Train RMSE: 0.0, Validation RMSE: 4.065613220345858

# %% [markdown]
# > Plot Tree diagram
# >
# > I will visualize the decision tree (graphically) and display feature importances as a graph while limiting the maximum depth of graphical visualization to 5 levels.

# %%
plt.figure(figsize=(30,15))

# Visualize the tree graphically using plot_tree
plot_tree(model1, max_depth=5, feature_names=train_inputs.columns,
         filled=True, rounded=True);

# %% [markdown]
# __Check feature importance__

# %%
tree_importances = model1.feature_importances_

# %%
tree_importance_df = pd.DataFrame({
    'feature': X_train.columns,
    'importance': tree_importances
}).sort_values('importance', ascending=False)

# %%
plt.title('Decision Tree Feature Importance')
sns.barplot(data=tree_importance_df.head(10), x='importance', y='feature');

# %% [markdown]
# ## Model Buidling with Random Forest

# %%
rfmodel = RandomForestRegressor(random_state=42, n_jobs=1) #train random forest regressor

# %%
rfmodel.fit(X_train, train_targets)     # fit train inputs
# Out:
# RandomForestRegressor(n_jobs=1, random_state=42)

# %%
rftrain_preds = rfmodel.predict(X_train)  #prediction

# %%
rf_train_rmse = mean_squared_error(rftrain_preds, train_targets, squared=False)
rf_train_rmse  # rmse loss
# Out:
# 0.5226382258426944

# %%
rfval_preds = rfmodel.predict(X_val)

# %%
rf_val_rmse = mean_squared_error(rfval_preds, val_targets, squared=False)
rf_val_rmse
# Out:
# 2.438246718635819

# %%
print('Train RMSE: {}, Validation RMSE: {}'.format(rf_train_rmse, rf_val_rmse))
# Out:
# Train RMSE: 0.5226382258426944, Validation RMSE: 2.438246718635819

# %% [markdown]
# > **Random forest tree**

# %%
plt.figure(figsize=(30,15))

# Visualize the tree graphically using plot_tree
plot_tree(model1, max_depth=5, feature_names=train_inputs.columns,
         filled=True, rounded=True);

# %% [markdown]
# ## Hyperparameter Tuning of Decison Trees Regressor Model

# %% [markdown]
# I will define a helper function `test_params` which can test the given value of one or more hyperparameters.
# I will also define a helper function to test and plot different values of a single parameter.

# %%
def test_params(**params):
    model = RandomForestRegressor(random_state=42, n_jobs=-1, **params).fit(X_train, train_targets)
    train_rmse = mean_squared_error(model.predict(X_train), train_targets, squared=False)
    val_rmse = mean_squared_error(model.predict(X_val), val_targets, squared=False)
    return train_rmse, val_rmse


def test_param_and_plot(param_name, param_values):
    train_errors, val_errors = [], [] 
    for value in param_values:
        params = {param_name: value}
        train_rmse, val_rmse = test_params(**params)
        train_errors.append(train_rmse)
        val_errors.append(val_rmse)
    plt.figure(figsize=(10,6))
    plt.title('Overfitting curve: ' + param_name)
    plt.plot(param_values, train_errors, 'b-o')
    plt.plot(param_values, val_errors, 'r-o')
    plt.xlabel(param_name)
    plt.ylabel('RMSE')
    plt.legend(['Training', 'Validation'])

# %%
test_params(n_estimators=1000, max_depth=20, min_samples_leaf=4, max_features=0.4, bootstrap=False)
# Out:
# (0.5968964520354565, 2.2598186469252783)

# %%
test_param_and_plot('max_depth', [5, 10, 15, 20, 25, 30, 35,50, 75, 100])

# %%
test_param_and_plot('min_samples_leaf', [5, 10, 15, 20, 25, 30, 35])

# %%
test_param_and_plot('max_features', [0.1, 0.3, 0.5, 0.7, 0.9])

# %% [markdown]
# ## Training Best model

# %% [markdown]
# > Train a random forest regressor model with your best hyperparameters to minimize the validation loss.

# %%
model = RandomForestRegressor(random_state=42,
                             n_jobs=-1, 
                             max_depth=20,
                             min_samples_leaf=3,
                             max_features=0.1,
                              n_estimators = 1000,
                             ).fit(X_train, train_targets)

# %%
# Train the model
preds = model.predict(X_train)

# %%
rmse = mean_squared_error(preds, train_targets, squared=False)
rmse
# Out:
# 1.0075917532375585

# %%
vals_pred = model.predict(X_val)

# %%
rmse_val = mean_squared_error(vals_pred, val_targets, squared=False)
rmse_val
# Out:
# 2.5185964719673515

# %%
model_importance_df = pd.DataFrame({
    'feature': X_train.columns,
    'importance': model.feature_importances_
}).sort_values('importance', ascending=False)

# %%
plt.title('Decision Tree Feature Importance')
sns.barplot(data=tree_importance_df.head(10), x='importance', y='feature');

# %% [markdown]
# ## Making Prdiction on test data

# %%
test = pd.read_csv('airbnb_test.csv')
test.head(3).T
# Out:
#                                                                  269443  \
# review_date                                                        2019
# Reviewer Name                                                  ValÃ©rie
# Comments              Das Apartment und das Wohnquartier ist einfach...
# Listing URL                         https://www.airbnb.com/rooms/267951
# Listing Name                       Modernes Apartment in Berlin PÂ´berg
# Host URL                      https://www.airbnb.com/users/show/1404760
# Host Name                                                         Frank
# Host Since                                                   2011-11-14
# Host Response Time                                       within an hour
# Host Response Rate                                                 100%
# Is Superhost                                                          t
# neighbourhood                                           Prenzlauer Berg
# ...

# %%
test_df[numVar] = scalar.transform(test_df[numVar])
test_df[encoded_cols] = encoder.transform(test_df[catVar])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12944\3582658961.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df[numVar] = scalar.transform(test_df[numVar])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12944\3582658961.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df[encoded_cols] = encoder.transform(test_df[catVar])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12944\3582658961.py:2: SettingWithCopyWarning:
# ...

# %%
test_inputs = test_df[numVar + encoded_cols]

# %%
test_preds = model.predict(test_inputs)

# %%
test_rmse = mean_squared_error(test_targets, test_preds, squared=False)
test_rmse
# Out:
# 9.747958775397773

# %% [markdown]
# > **The RMSE LOSS for the test data is 9**
